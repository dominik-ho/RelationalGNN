# %%
from networkx import MultiDiGraph

# %%
g = MultiDiGraph()

# %%
g.add_nodes_from(range(10), type="number")

# %%
g.nodes.data()
# Out:
# NodeDataView({0: {'type': 'number'}, 1: {'type': 'number'}, 2: {'type': 'number'}, 3: {'type': 'number'}, 4: {'type': 'number'}, 5: {'type': 'number'}, 6: {'type': 'number'}, 7: {'type': 'number'}, 8: {'type': 'number'}, 9: {'type': 'number'}})

# %%
g.add_edge(0, 1, att1=1)
# Out:
# 0

# %%
g.edges.data()
# Out:
# OutMultiEdgeDataView([(0, 1, {'att1': 1})])

# %%
g.add_edge(0, 1, att1=2)
g.edges.data()
# Out:
# OutMultiEdgeDataView([(0, 1, {'att1': 1}), (0, 1, {'att1': 2})])
