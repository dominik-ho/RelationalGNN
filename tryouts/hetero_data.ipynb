# %%
from torch_geometric.data import HeteroData
import torch

# %%
data = HeteroData()

# %%
data.obj_names = ["a", "b", "c"]

# %%
data
# Out:
# HeteroData(
#   obj_names=[3]
# )

# %%
edge_type = ("obj", "0", "bla")
data[edge_type].edge_index = torch.randint(0, 10, (2, 100))

# %%
data.edge_types
# Out:
# [('obj', '0', 'bla')]
